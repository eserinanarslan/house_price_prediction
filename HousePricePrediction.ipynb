# %% [markdown]
# # **House Price Prediction by Average Price Method**

# %%
import pandas as pd
import numpy as np

from google.colab import files

# %%
#Upload train data set file from local to colabs area
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c97870e-b348-4564-8c7b-2aa3f96d8200" name="files[]" multiple disabled />
#      <output id="result-9c97870e-b348-4564-8c7b-2aa3f96d8200">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
# Load Train dataset
train = pd.read_csv("train.csv")
train.head(5).append(train.tail(5))
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [10 rows x 81 columns]

# %%
#Upload test data set file from local to colabs area
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9872a365-09f3-43fb-bbeb-7baccf9d6d5a" name="files[]" multiple disabled />
#      <output id="result-9872a365-09f3-43fb-bbeb-7baccf9d6d5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
# Load Test dataset
test = pd.read_csv("test.csv")
test.head(5).append(test.tail(5))
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [10 rows x 80 columns]

# %%
test.shape
# Out:
# (1459, 80)

# %%
train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
#          ...
# 1430    192140
# 1431    143750
# 1432     64500
# 1433    186500
# 1434    160000
# 1435    174000
# 1436    120500
# 1437    394617
# 1438    149700
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    310000
# 1443    121000
# 1444    179600
# 1445    129000
# 1446    157900
# 1447    240000
# 1448    112000
# 1449     92000
# 1450    136000
# 1451    287090
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    210000
# ...

# %%
#Calculate average of SalePrice of train data set
sale_pricce_average = np.average(train['SalePrice'])

# %%
sale_pricce_average
# Out:
# 180921.19589041095

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
test.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# ...

# %%
#Create result dataframe
result_df = pd.DataFrame()

# %%
#Copy house Id from test data set
result_df['Id'] = test['Id'].astype(np.int64)

# %%
#Set result saleprice
result_df["SalePrice"] = sale_pricce_average

# %%
result_df
# Out:
#         Id     SalePrice
# 0     1461  180921.19589
# 1     1462  180921.19589
# 2     1463  180921.19589
# 3     1464  180921.19589
# 4     1465  180921.19589
# 5     1466  180921.19589
# 6     1467  180921.19589
# 7     1468  180921.19589
# 8     1469  180921.19589
# 9     1470  180921.19589
# 10    1471  180921.19589
# 11    1472  180921.19589
# 12    1473  180921.19589
# 13    1474  180921.19589
# 14    1475  180921.19589
# 15    1476  180921.19589
# 16    1477  180921.19589
# 17    1478  180921.19589
# 18    1479  180921.19589
# 19    1480  180921.19589
# 20    1481  180921.19589
# 21    1482  180921.19589
# 22    1483  180921.19589
# 23    1484  180921.19589
# 24    1485  180921.19589
# 25    1486  180921.19589
# 26    1487  180921.19589
# 27    1488  180921.19589
# 28    1489  180921.19589
# 29    1490  180921.19589
# ...    ...           ...
# 1429  2890  180921.19589
# 1430  2891  180921.19589
# 1431  2892  180921.19589
# 1432  2893  180921.19589
# 1433  2894  180921.19589
# ...

# %%
result_df.dtypes
# Out:
# Id             int64
# SalePrice    float64
# dtype: object

# %%
#Export dataframe as a csv
result_df.to_csv("result_submission.csv", index=0)
